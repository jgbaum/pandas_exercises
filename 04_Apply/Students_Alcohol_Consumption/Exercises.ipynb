# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv')

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df_slice = df.loc[:,'school':'guardian']
# Out:
# school      object
# sex         object
# age          int64
# address     object
# famsize     object
# Pstatus     object
# Medu         int64
# Fedu         int64
# Mjob        object
# Fjob        object
# reason      object
# guardian    object
# dtype: object

# %% [markdown]
# ### Step 5. Create a lambda function that will capitalize strings.

# %%
capitalizer = lambda x: x.capitalize()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
# first convert the columns to strings
df_slice['Mjob'] = df_slice['Mjob'].astype('string')
df_slice['Fjob'] = df_slice['Fjob'].astype('string')

df_slice['Mjob'] = df_slice['Mjob'].apply(capitalizer)
df_slice['Fjob'] = df_slice['Fjob'].apply(capitalizer)

df_slice.dtypes
# Out:
# school      object
# sex         object
# age          int64
# address     object
# famsize     object
# Pstatus     object
# Medu         int64
# Fedu         int64
# Mjob        object
# Fjob        object
# reason      object
# guardian    object
# dtype: object

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

# %%
df['Mjob'] = df['Mjob'].astype('string')
df['Fjob'] = df['Fjob'].astype('string')

df['Mjob'] = df['Mjob'].apply(capitalizer)
df['Fjob'] = df['Fjob'].apply(capitalizer)

df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  Services  Services
# 391     MS   M   17       U     LE3       T     3     1  Services  Services
# 392     MS   M   21       R     GT3       T     1     1     Other     Other
# 393     MS   M   18       R     LE3       T     3     2  Services     Other
# 394     MS   M   19       U     LE3       T     1     1     Other   At_home
#
# ...

# %% [markdown]
# ### Step 9. Create a function called majority that returns a boolean value to a new column called legal_drinker (Consider majority as older than 17 years old)

# %%
def majority(df: pd.DataFrame) -> pd.DataFrame:
  df['legal_drinker'] = df['age'] > 17
  return df

# %%
df_slice = majority(df_slice)
df_slice
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu  \
# 0       GP   F   18       U     GT3       A     4     4
# 1       GP   F   17       U     GT3       T     1     1
# 2       GP   F   15       U     LE3       T     1     1
# 3       GP   F   15       U     GT3       T     4     2
# 4       GP   F   16       U     GT3       T     3     3
# ..     ...  ..  ...     ...     ...     ...   ...   ...
# 390     MS   M   20       U     LE3       A     2     2
# 391     MS   M   17       U     LE3       T     3     1
# 392     MS   M   21       R     GT3       T     1     1
# 393     MS   M   18       R     LE3       T     3     2
# 394     MS   M   19       U     LE3       T     1     1
#
#                                                   Mjob      Fjob  reason  \
# 0    0      0      0       at_home\n1       at_home...   Teacher  course
# 1    0      0      0       at_home\n1       at_home...     Other  course
# ...

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
df_slice.select_dtypes(include='number').apply(lambda x: x * 10)
# Out:
#      age  Medu  Fedu
# 0    180    40    40
# 1    170    10    10
# 2    150    10    10
# 3    150    40    20
# 4    160    30    30
# ..   ...   ...   ...
# 390  200    20    20
# 391  170    30    10
# 392  210    10    10
# 393  180    30    20
# 394  190    10    10
#
# [395 rows x 3 columns]

# %%
def times10(x):
    if type(x) is int:
        return 10 * x
    return x

df_slice.applymap(times10)
# Out:
# /tmp/ipython-input-2346494446.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_slice.applymap(times10)
#     school sex  age address famsize Pstatus  Medu  Fedu  \
# 0       GP   F  180       U     GT3       A    40    40
# 1       GP   F  170       U     GT3       T    10    10
# 2       GP   F  150       U     LE3       T    10    10
# 3       GP   F  150       U     GT3       T    40    20
# 4       GP   F  160       U     GT3       T    30    30
# ..     ...  ..  ...     ...     ...     ...   ...   ...
# 390     MS   M  200       U     LE3       A    20    20
# 391     MS   M  170       U     LE3       T    30    10
# 392     MS   M  210       R     GT3       T    10    10
# 393     MS   M  180       R     LE3       T    30    20
# 394     MS   M  190       U     LE3       T    10    10
#
#                                                   Mjob      Fjob  reason  \
# ...
