# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
# first convert the item_price to a float
dollarizer = lambda x: float(x[1:-1])
chipo['item_price'] = chipo['item_price'].apply(dollarizer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1545410086.py in <cell line: 0>()
#       1 # first convert the item_price to a float
#       2 dollarizer = lambda x: float(x[1:-1])
# ----> 3 chipo['item_price'] = chipo['item_price'].apply(dollarizer)
#       4 chipo['item_price'] > 10
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply_standard(self)
# ...

# %%
#chipo['item_name','item_price'][chipo['item_price'] > 10]
#chipo[['item_name','item_price']].loc(chipo['item_price'] > 10)
chipo[['item_name','item_price']].loc[chipo.item_price > 10]
# Out:
#                item_name  item_price
# 4           Chicken Bowl       16.98
# 5           Chicken Bowl       10.98
# 7          Steak Burrito       11.75
# 13          Chicken Bowl       11.25
# 23       Chicken Burrito       10.98
# ...                  ...         ...
# 4610       Steak Burrito       11.75
# 4611      Veggie Burrito       11.25
# 4617       Steak Burrito       11.75
# 4618       Steak Burrito       11.75
# 4619  Chicken Salad Bowl       11.25
#
# [1130 rows x 2 columns]

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only three columns item_name choice_description and product_price

# %%
chipo[['item_name','choice_description','item_price']].drop_duplicates()
# Out:
#                                   item_name  \
# 0              Chips and Fresh Tomato Salsa
# 1                                      Izze
# 2                          Nantucket Nectar
# 3     Chips and Tomatillo-Green Chili Salsa
# 4                              Chicken Bowl
# ...                                     ...
# 4602                       Barbacoa Burrito
# 4607                          Steak Burrito
# 4610                          Steak Burrito
# 4611                         Veggie Burrito
# 4612                          Carnitas Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 3                                                   NaN        2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo[['item_name','choice_description','item_price']].drop_duplicates().sort_values('item_name')
# Out:
#               item_name                                 choice_description  \
# 3141  6 Pack Soft Drink                                         [Lemonade]
# 341   6 Pack Soft Drink                                        [Diet Coke]
# 357   6 Pack Soft Drink                                             [Coke]
# 298   6 Pack Soft Drink                                           [Sprite]
# 3389  6 Pack Soft Drink                                        [Diet Coke]
# ...                 ...                                                ...
# 738   Veggie Soft Tacos  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 1699  Veggie Soft Tacos  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 2851  Veggie Soft Tacos  [Roasted Chili Corn Salsa (Medium), [Black Bea...
# 2384  Veggie Soft Tacos  [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# 3889  Veggie Soft Tacos  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...
#
#       item_price
# 3141        6.49
# 341         6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo[['item_name','quantity','item_price']].sort_values('item_price', ascending=False).head(1)['quantity']
# Out:
# 3598    15
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo[chipo['item_name'] == 'Veggie Salad Bowl'].shape[0]
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo[(chipo['item_name'] == 'Canned Soda') & (chipo['quantity'] > 1)].shape[0]
# Out:
# 20
