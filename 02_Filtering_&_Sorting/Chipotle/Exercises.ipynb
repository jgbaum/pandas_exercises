# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
# first convert the item_price to a float
dollarizer = lambda x: float(x[1:-1])
chipo['item_price'] = chipo['item_price'].apply(dollarizer)

# %%
# next recover the product price by dividing by the quanity
chipo['product_price'] = chipo.item_price / chipo.quantity
# now filter for product price greater than 10 after removing duplicate item names & descriptions
filtered_chipo = chipo.drop_duplicates(['item_name','choice_description'])
filtered_chipo = filtered_chipo[filtered_chipo['product_price'] > 10]
filtered_chipo
# Out:
#       order_id  quantity        item_name  \
# 5            3         1     Chicken Bowl
# 7            4         1    Steak Burrito
# 13           7         1     Chicken Bowl
# 23          12         1  Chicken Burrito
# 39          19         1    Barbacoa Bowl
# ...        ...       ...              ...
# 4593      1825         1    Carnitas Bowl
# 4594      1825         1    Barbacoa Bowl
# 4607      1829         1    Steak Burrito
# 4610      1830         1    Steak Burrito
# 4611      1830         1   Veggie Burrito
#
#                                      choice_description  item_price  \
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# 39    [Roasted Chili Corn Salsa, [Fajita Vegetables,...       11.75
# ...

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only three columns item_name choice_description and product_price

# %%
filtered_chipo[['item_name','choice_description','product_price']].drop_duplicates()
# Out:
#             item_name                                 choice_description  \
# 5        Chicken Bowl  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 7       Steak Burrito  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 13       Chicken Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 23    Chicken Burrito  [[Tomatillo-Green Chili Salsa (Medium), Tomati...
# 39      Barbacoa Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# ...               ...                                                ...
# 4593    Carnitas Bowl  [Roasted Chili Corn Salsa, [Rice, Sour Cream, ...
# 4594    Barbacoa Bowl  [Roasted Chili Corn Salsa, [Pinto Beans, Sour ...
# 4607    Steak Burrito  [Tomatillo Green Chili Salsa, [Rice, Cheese, S...
# 4610    Steak Burrito  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4611   Veggie Burrito  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...
#
#       product_price
# 5             10.98
# 7             11.75
# 13            11.25
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
filtered_chipo[['item_name','choice_description','product_price']].drop_duplicates().sort_values('item_name')

# or

filtered_chipo.sort_values('item_name')

# or

filtered_chipo.item_name.sort_values()
# Out:
# 2749        Barbacoa Bowl
# 2762        Barbacoa Bowl
# 4046        Barbacoa Bowl
# 3547        Barbacoa Bowl
# 919         Barbacoa Bowl
#               ...
# 496     Veggie Salad Bowl
# 186     Veggie Salad Bowl
# 4201    Veggie Salad Bowl
# 738     Veggie Soft Tacos
# 1699    Veggie Soft Tacos
# Name: item_name, Length: 707, dtype: object

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo[['item_name','quantity','item_price']].sort_values('item_price', ascending=False).head(1)['quantity']

# or

chipo.loc[chipo.item_price.idxmax()]['quantity']
# Out:
# np.int64(15)

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo[chipo['item_name'] == 'Veggie Salad Bowl']['quantity'].sum()
# Out:
# np.int64(18)

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo[(chipo['item_name'] == 'Canned Soda') & (chipo['quantity'] > 1)].shape[0]
# Out:
# 20
