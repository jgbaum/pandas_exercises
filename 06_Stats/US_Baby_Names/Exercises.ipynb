# %% [markdown]
# # US - Baby Names

# %% [markdown]
# ### Introduction:
#
# We are going to use a subset of [US Baby Names](https://www.kaggle.com/kaggle/us-baby-names) from Kaggle.
# In the file it will be names from 2004 until 2014
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called baby_names.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
df.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %% [markdown]
# ### Step 5. Delete the column 'Unnamed: 0' and 'Id'

# %%
df = df.drop(labels=['Unnamed: 0', 'Id'], axis=1)
df.head()
# Out:
#       Name  Year Gender State  Count
# 0     Emma  2004      F    AK     62
# 1  Madison  2004      F    AK     48
# 2   Hannah  2004      F    AK     46
# 3    Grace  2004      F    AK     44
# 4    Emily  2004      F    AK     41

# %% [markdown]
# ### Step 6. What year has the highest number of baby names in the dataset?

# %%
df[['Count','Year']].groupby('Year').sum().idxmax()
# Out:
# Count    2007
# dtype: int64

# %% [markdown]
# ### Step 7. Is there more male or female names in the dataset?

# %%
df[['Gender','Name']].drop_duplicates().groupby(['Gender']).count()
# Out:
#          Name
# Gender
# F       10929
# M        8012

# %% [markdown]
# ### Step 8. Group the dataset by name and assign to names

# %%
names_df = df.groupby(['Name']).sum()

# %% [markdown]
# ### Step 9. How many different names exist in the dataset?

# %%
df['Name'].drop_duplicates().count()
# Out:
# np.int64(17632)

# %% [markdown]
# ### Step 10. What is the name with most occurrences?

# %%
df.groupby(['Name']).sum().sort_values('Count',ascending=False).idxmax()
# Out:
# Year        Riley
# Gender     Oliver
# State     Coalton
# Count       Jacob
# dtype: object

# %% [markdown]
# ### Step 11. How many different names have the least occurrences?

# %%
len(names_df[names_df.Count == names_df.Count.min()])
# Out:
# 2578

# %% [markdown]
# ### Step 12. What is the median name occurrence?

# %%
names_df.Count.median()
# Out:
# 49.0

# %% [markdown]
# ### Step 13. What is the standard deviation of names?

# %%
names_df.Count.std()
# Out:
# count     17632.000000
# mean       2008.932169
# std       11006.069468
# min           5.000000
# 25%          11.000000
# 50%          49.000000
# 75%         337.000000
# max      242874.000000
# Name: Count, dtype: float64

# %% [markdown]
# ### Step 14. Get a summary with the mean, min, max, std and quartiles.

# %%
names_df.Count.describe()
# Out:
# count     17632.000000
# mean       2008.932169
# std       11006.069468
# min           5.000000
# 25%          11.000000
# 50%          49.000000
# 75%         337.000000
# max      242874.000000
# Name: Count, dtype: float64
